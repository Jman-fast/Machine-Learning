# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
df=pd.read_csv('train.csv')

# %%
print(df.isnull().sum())
# Out:
# id               0
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# sunshine         0
# winddirection    0
# windspeed        0
# rainfall         0
# dtype: int64

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of         id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 0        0    1    1017.4     21.2         20.6     19.9      19.4      87.0
# 1        1    2    1019.5     16.2         16.9     15.8      15.4      95.0
# 2        2    3    1024.1     19.4         16.1     14.6       9.3      75.0
# 3        3    4    1013.4     18.1         17.8     16.9      16.8      95.0
# 4        4    5    1021.8     21.3         18.4     15.2       9.6      52.0
# ...    ...  ...       ...      ...          ...      ...       ...       ...
# 2185  2185  361    1014.6     23.2         20.6     19.1      19.9      97.0
# 2186  2186  362    1012.4     17.2         17.3     16.3      15.3      91.0
# 2187  2187  363    1013.3     19.0         16.3     14.3      12.6      79.0
# 2188  2188  364    1022.3     16.4         15.2     13.8      14.7      92.0
# 2189  2189  365    1013.8     21.2         19.1     18.0      18.0      89.0
#
# ...

# %%
X = df[['pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint', 'humidity', 'cloud', 'sunshine', 'winddirection', 'windspeed']]
y = df['rainfall']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(X_train)
scaled_df = pd.DataFrame(scaled_data, columns = X_train.columns)
scaled_df.head()
# Out:
#    pressure   maxtemp  temparature   mintemp  dewpoint  humidity     cloud  \
# 0  0.292135  0.789062     0.867220  0.872093  0.922222  0.745763  0.877551
# 1  0.474719  0.714844     0.759336  0.643411  0.748148  0.440678  0.500000
# 2  0.564607  0.359375     0.423237  0.507752  0.607407  0.898305  0.836735
# 3  0.463483  0.773438     0.842324  0.794574  0.785185  0.627119  0.673469
# 4  0.623596  0.191406     0.215768  0.294574  0.414815  0.881356  0.795918
#
#    sunshine  winddirection  windspeed
# 0  0.441667       0.724138   0.080000
# 1  0.783333       0.206897   0.298182
# 2  0.000000       0.206897   0.525455
# 3  0.641667       0.206897   0.069091
# 4  0.183333       0.103448   0.278182

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(X_test)
scaled_df = pd.DataFrame(scaled_data, columns = X_test.columns)
scaled_df.head()
# Out:
#    pressure   maxtemp  temparature   mintemp  dewpoint  humidity     cloud  \
# 0  0.741573  0.137441     0.205405  0.295337  0.484375  0.500000  0.879518
# 1  0.581461  0.094787     0.118919  0.150259  0.562500  1.000000  1.000000
# 2  0.317416  0.786730     0.870270  0.865285  0.972656  0.739130  0.795181
# 3  0.508427  0.099526     0.200000  0.305699  0.578125  0.934783  0.951807
# 4  0.266854  0.763033     0.837838  0.849741  0.945312  0.630435  0.734940
#
#    sunshine  winddirection  windspeed
# 0  0.082645       0.034483   0.403131
# 1  0.000000       0.241379   0.712329
# 2  0.528926       0.482759   0.430528
# 3  0.000000       0.103448   0.315068
# 4  0.371901       0.068966   0.236791

# %%
regr = linear_model.LogisticRegression()
regr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = regr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.86

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.62      0.69       111
#            1       0.88      0.94      0.91       327
#
#     accuracy                           0.86       438
#    macro avg       0.83      0.78      0.80       438
# weighted avg       0.85      0.86      0.85       438

# %%
#applying this model on the test dataset

# %%
df = pd.read_csv('test.csv')

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of        id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 0    2190    1    1019.5     17.5         15.8     12.7      14.9      96.0
# 1    2191    2    1016.5     17.5         16.5     15.8      15.1      97.0
# 2    2192    3    1023.9     11.2         10.4      9.4       8.9      86.0
# 3    2193    4    1022.9     20.6         17.3     15.2       9.5      75.0
# 4    2194    5    1022.2     16.1         13.8      6.4       4.3      68.0
# ..    ...  ...       ...      ...          ...      ...       ...       ...
# 725  2915  361    1020.8     18.2         17.6     16.1      13.7      96.0
# 726  2916  362    1011.7     23.2         18.1     16.0      16.0      78.0
# 727  2917  363    1022.7     21.0         18.5     17.0      15.5      92.0
# 728  2918  364    1014.4     21.0         20.0     19.7      19.8      94.0
# 729  2919  365    1020.9     22.2         18.8     17.0      13.3      79.0
#
# ...

# %%
X = df[['pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint', 'humidity', 'cloud', 'sunshine', 'winddirection', 'windspeed']]
y = ['rainfall']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(X)
scaled_df = pd.DataFrame(scaled_data, columns = X.columns)
scaled_df.head()
# Out:
#    pressure   maxtemp  temparature   mintemp  dewpoint  humidity  cloud  \
# 0  0.605590  0.355634     0.382239  0.341365  0.558052  0.966102   0.99
# 1  0.512422  0.355634     0.409266  0.465863  0.565543  0.983051   0.99
# 2  0.742236  0.133803     0.173745  0.208835  0.333333  0.796610   0.96
# 3  0.711180  0.464789     0.440154  0.441767  0.355805  0.610169   0.45
# 4  0.689441  0.306338     0.305019  0.088353  0.161049  0.491525   0.49
#
#    sunshine  winddirection  windspeed
# 0  0.000000       0.137931   0.360000
# 1  0.000000       0.137931   0.560000
# 2  0.000000       0.103448   0.225455
# 3  0.601695       0.034483   0.838182
# 4  0.779661       0.034483   0.270909

# %%
y = regr.predict(scaled_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-cc0cbd78cabc> in <cell line: 0>()
# ----> 1 y = regr.predict(scaled_df)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     372         """
#     373         xp, _ = get_namespace(X)
# --> 374         scores = self.decision_function(X)
#     375         if len(scores.shape) == 1:
#     376             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     349         xp, _ = get_namespace(X)
#     350
# --> 351         X = validate_data(self, X, accept_sparse="csr", reset=False)
#     352         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     353         return (
#
# ...

# %%
print(scaled_df.isnull().sum())
# Out:
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# sunshine         0
# winddirection    1
# windspeed        0
# dtype: int64

# %%
missing_value_row = scaled_df[scaled_df['winddirection'].isnull()]
print("Row(s) with missing values before replacement:")
print(missing_value_row)
# Out:
# Row(s) with missing values before replacement:
#      pressure   maxtemp  temparature   mintemp  dewpoint  humidity  cloud  \
# 517  0.242236  0.897887     0.953668  0.991968   0.82397  0.440678   0.75
#
#      sunshine  winddirection  windspeed
# 517  0.694915            NaN   0.230909

# %%
scaled_df['winddirection'].fillna(scaled_df['winddirection'].mean(), inplace = True)
# Out:
# <ipython-input-35-603275e472a2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   scaled_df['winddirection'].fillna(scaled_df['winddirection'].mean(), inplace = True)

# %%
print(scaled_df.loc[missing_value_row.index, 'winddirection'])
# Out:
# 517    0.323873
# Name: winddirection, dtype: float64

# %%
y = regr.predict(scaled_df)

# %%
start_index = 2190
index_values = range(start_index, start_index + len(y))

# %%
df_predictions = pd.DataFrame({'id':index_values, 'rainfall':y})

# %%
df_predictions.to_csv("predicted_data.csv", index = False)

# %%
from google.colab import files
files.download("predicted_data.csv")
